# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

Y = 0.5
Sf = 10
Ks = 1
mu = 0.2

def graph(formula, D_range):  
    D = np.array(D_range)  
    DX = (D*Y/2)*(Sf   -   (Ks / ( (mu/D)  -1)  )    ) 
    plt.plot(D, DX) 
    plt.xlabel(r'D $(h^{-1})$', fontsize = 14)
    plt.ylabel(r'DX $( \frac{g}{L*h} )$', fontsize = 14)
    plt.title('Problem 2d')
    plt.show() 

def my_formula(t):
    return (D*Y/2)*(Sf   -   (Ks / ( (mu/D)  -1)  )    ) 

graph(my_formula, np.linspace(0.01,0.18,1000))
